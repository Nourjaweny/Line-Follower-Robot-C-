# %% [markdown]
# <a href="https://colab.research.google.com/github/Nourjaweny/Line-Follower-Robot-C-/blob/main/Visualization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
data_sleep=pd.read_csv("/content/Sleep_Efficiency.csv")
data_sleep.tail()
# Out:
#       ID  Age  Gender              Bedtime          Wakeup time  \
# 447  448   27  Female  2021-11-13 22:00:00  2021-11-13 05:30:00
# 448  449   52    Male  2021-03-31 21:00:00  2021-03-31 03:00:00
# 449  450   40  Female  2021-09-07 23:00:00  2021-09-07 07:30:00
# 450  451   45    Male  2021-07-29 21:00:00  2021-07-29 04:00:00
# 451  452   18    Male  2021-03-17 02:30:00  2021-03-17 10:00:00
#
#      Sleep duration  Sleep efficiency  REM sleep percentage  \
# 447             7.5              0.91                    22
# 448             6.0              0.74                    28
# 449             8.5              0.55                    20
# 450             7.0              0.76                    18
# 451             7.5              0.63                    22
#
#      Deep sleep percentage  Light sleep percentage  Awakenings  \
# 447                     57                      21         0.0
# 448                     57                      15         4.0
# ...

# %%
print(data_sleep.shape)
# Out:
# (452, 15)

# %%
print(data_sleep['Sleep duration'].dtype)
# Out:
# float64

# %%
data_sleep
# Out:
#       ID  Age  Gender              Bedtime          Wakeup time  \
# 0      1   65  Female  2021-03-06 01:00:00  2021-03-06 07:00:00
# 1      2   69    Male  2021-12-05 02:00:00  2021-12-05 09:00:00
# 2      3   40  Female  2021-05-25 21:30:00  2021-05-25 05:30:00
# 3      4   40  Female  2021-11-03 02:30:00  2021-11-03 08:30:00
# 4      5   57    Male  2021-03-13 01:00:00  2021-03-13 09:00:00
# ..   ...  ...     ...                  ...                  ...
# 447  448   27  Female  2021-11-13 22:00:00  2021-11-13 05:30:00
# 448  449   52    Male  2021-03-31 21:00:00  2021-03-31 03:00:00
# 449  450   40  Female  2021-09-07 23:00:00  2021-09-07 07:30:00
# 450  451   45    Male  2021-07-29 21:00:00  2021-07-29 04:00:00
# 451  452   18    Male  2021-03-17 02:30:00  2021-03-17 10:00:00
#
#      Sleep duration  Sleep efficiency  REM sleep percentage  \
# 0               6.0              0.88                    18
# 1               7.0              0.66                    19
# ...

# %%
data_sleep.to_csv("new_data.csv")

# %%
sns.histplot(data_sleep['Sleep duration'])
plt.title("Distribution de l'heure")
plt.show()

# %%
sns.lineplot(x='Age', y='Sleep duration', data=data_sleep)
plt.title("durée de sommeil en fonction de l'age")
plt.show()

# %%
import matplotlib.pyplot as plt
plt.pie(data_sleep['Smoking status'].value_counts(), labels=data_sleep['Smoking status'].unique(), autopct='%1.1f%%')
plt.title('Répartition des fumeurs')
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import pandas as pd


data_sleep['Bedtime'] = pd.to_datetime(data_sleep['Bedtime'])
data_sleep['Wakeup time'] = pd.to_datetime(data_sleep['Wakeup time'])
data_sleep['Sleep Duration1'] = data_sleep['Wakeup time'] - data_sleep['Bedtime']
duration_components = data_sleep['Sleep Duration1'].dt.components
data_sleep['Sleep Duration (hours)'] = duration_components['hours'] + duration_components['minutes'] / 60 + duration_components['seconds'] / 3600

print(data_sleep)
